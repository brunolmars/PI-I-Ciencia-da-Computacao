# %% [markdown]
# <a href="https://colab.research.google.com/github/brunolmars/PI-I-Ciencia-da-Computacao/blob/main/database/Data_forms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
from IPython.display import display
from google.colab import files

drive.mount('/content/drive')

NOME_ARQUIVO_FORM = '/content/drive/MyDrive/respostas_formulario.csv'

def extrair_dados_form(nome_arquivo):
    """Carrega o arquivo CSV do Google Form."""
    try:
        df_bruto = pd.read_csv(nome_arquivo, sep=',', encoding='utf-8')

        print(f"\nSucesso! {len(df_bruto)} respostas encontradas no arquivo.")
        return df_bruto

    except FileNotFoundError:
        print(f"\nERRO DE EXTRAÇÃO: Arquivo '{nome_arquivo}' não encontrado.")
        print("Certifique-se de que o caminho acima está EXATO (incluindo letras maiúsculas/minúsculas da pasta).")
        return pd.DataFrame()
    except Exception as e:
        print(f"\nERRO DE LEITURA: Não foi possível ler o arquivo. Erro: {e}")
        return pd.DataFrame()


df_bruto = extrair_dados_form(NOME_ARQUIVO_FORM)

if not df_bruto.empty:
    print("\n✅ DataFrame Bruto carregado na variável 'df_bruto'.")
    print("Use os nomes das colunas abaixo para renomeá-las na Célula 2.")
    display(df_bruto.head())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#
# Sucesso! 137 respostas encontradas no arquivo.
#
# ✅ DataFrame Bruto carregado na variável 'df_bruto'.
# Use os nomes das colunas abaixo para renomeá-las na Célula 2.
#   Faixa etária                     Participa de apostas Reserva financeira  \
# 0      18 - 25         Não participo desse tipo de jogo                Não
# 1        41-60         Não participo desse tipo de jogo                Não
# 2          60+  Sim, mas de forma eventual e controlada                Não
# 3          60+  Sim, mas de forma eventual e controlada                Não
# 4        41-60  Sim, mas de forma eventual e controlada                Não
#
#        Resgate imediato Poupança  \
# 0                   Não      Não
# 1                   Sim      Não
# 2  Não possuo a reserva      Não
# 3                   Não      Sim
# 4  Não possuo a reserva      Sim
#
#                                     Tesouro Nacional  \
# 0                                                Sim
# 1                                                Não
# 2                                                Não
# 3                                                Não
# 4  Não tenho conhecimento sobre esse tipo de inve...
#
#                                           Renda fixa  \
# 0                                                Sim
# 1                                                Sim
# 2  Não tenho conhecimento sobre esse tipo de inve...
# 3                                                Sim
# 4  Não tenho conhecimento sobre esse tipo de inve...
#
#                                       Renda variável  \
# 0  Não tenho conhecimento sobre esse tipo de inve...
# 1  Não tenho conhecimento sobre esse tipo de inve...
# 2  Não tenho conhecimento sobre esse tipo de inve...
# 3                                                Não
# 4                                                Não
#
#                                     Reserva de valor Nível de conhecimento  \
# 0                                                Não         Intermediário
# 1  Não tenho conhecimento sobre esse tipo de inve...             Iniciante
# 2                                                Não             Iniciante
# 3                                                Sim             Iniciante
# 4  Não tenho conhecimento sobre esse tipo de inve...              Avançado
#
#                                  Objetivo financeiro  \
# 0                                   Comprar uma casa
# 1  Juntar dinheiro para uma meta de curto prazo (...
# 2  Juntar dinheiro para uma meta de curto prazo (...
# 3                               Construir patrimônio
# 4                                     Viver de renda
#
#                                   Decisão financeira  \
# 0  Estou disposto(a) a aprender e assumir novas e...
# 1         Busco equilibrar segurança e rentabilidade
# 2  Prefiro decisões seguras, mesmo que o retorno ...
# 3  Estou disposto(a) a aprender e assumir novas e...
# 4  Prefiro decisões seguras, mesmo que o retorno ...
#
#                       Jornada financeira (opcional)  \
# 0     Pretendo criar uma reserva financeira sólida.
# 1  Aprendi que cada pequena economia faz diferença.
# 2        Sonho em viver de renda passiva no futuro.
# 3        Meu objetivo é diversificar investimentos.
# 4             Aprendi a importância de poupar cedo.
#
#                       Conselho financeiro (opcional)         E-mail (opcional)
# 0  Aprender sobre finanças é tão importante quant...      joao.silva@gmail.com
# 1  Diversifique seus investimentos para reduzir r...   pedro.almeida@gmail.com
# 2  Equilibre segurança e rentabilidade nos invest...    rafael.costa@gmail.com
# 3        Comece a poupar cedo, mesmo que seja pouco.    carla.santos@gmail.com
# 4  Evite dívidas desnecessárias e priorize invest...  juliana.farias@gmail.com

# %%
df_limpo = df_bruto.copy()

df_limpo = df_bruto.rename(columns={
    'Faixa etária': 'faixa_etaria',
    'Participa de apostas': 'participa_apostas',
    'Reserva financeira': 'reserva_financeira',
    'Resgate imediato': 'resgate_imediato',
    'Poupança': 'poupanca',
    'Tesouro Nacional': 'tesouro',
    'Renda fixa': 'renda_fixa',
    'Renda variável': 'renda_variavel',
    'Reserva de valor': 'reserva_valor',
    'Nível de conhecimento': 'nivel_conhecimento',
    'Objetivo financeiro': 'objetivo_financeiro',
    'Decisão financeira': 'decisao_financeira',
    'Jornada financeira (opcional)': 'jornada_financeira',
    'Conselho financeiro (opcional)': 'conselho_financeiro',
    'E-mail (opcional)': 'email'
}, inplace=False)
for col in ['faixa_etaria', 'nivel_conhecimento', 'reserva_financeira', 'participa_apostas']:
    if col in df_limpo.columns:
        df_limpo[col] = df_limpo[col].astype(str).str.strip().str.title()

for col in ['jornada_financeira', 'conselho_financeiro']:
    if col in df_limpo.columns:
        df_limpo[col] = df_limpo[col].astype(str).str.strip()

if 'email' in df_limpo.columns:
    df_limpo['email'] = df_limpo['email'].astype(str).str.strip().str.lower()


CAMINHO_LOCAL = "respostas_formulario_LIMPO.csv"
df_limpo.to_csv(CAMINHO_LOCAL, index=False, encoding="utf-8")
files.download(CAMINHO_LOCAL)

print("✔ Arquivo CSV gerado com sucesso:")
print(CAMINHO_LOCAL)

df_limpo.head()
# Out:
# ✔ Arquivo CSV gerado com sucesso:
# respostas_formulario_LIMPO.csv
#   faixa_etaria                        participa_apostas reserva_financeira  \
# 0      18 - 25         Não Participo Desse Tipo De Jogo                Não
# 1        41-60         Não Participo Desse Tipo De Jogo                Não
# 2          60+  Sim, Mas De Forma Eventual E Controlada                Não
# 3          60+  Sim, Mas De Forma Eventual E Controlada                Não
# 4        41-60  Sim, Mas De Forma Eventual E Controlada                Não
#
#        resgate_imediato poupanca  \
# 0                   Não      Não
# 1                   Sim      Não
# 2  Não possuo a reserva      Não
# 3                   Não      Sim
# 4  Não possuo a reserva      Sim
#
#                                              tesouro  \
# 0                                                Sim
# 1                                                Não
# 2                                                Não
# 3                                                Não
# 4  Não tenho conhecimento sobre esse tipo de inve...
#
#                                           renda_fixa  \
# 0                                                Sim
# 1                                                Sim
# 2  Não tenho conhecimento sobre esse tipo de inve...
# 3                                                Sim
# 4  Não tenho conhecimento sobre esse tipo de inve...
#
#                                       renda_variavel  \
# 0  Não tenho conhecimento sobre esse tipo de inve...
# 1  Não tenho conhecimento sobre esse tipo de inve...
# 2  Não tenho conhecimento sobre esse tipo de inve...
# 3                                                Não
# 4                                                Não
#
#                                        reserva_valor nivel_conhecimento  \
# 0                                                Não      Intermediário
# 1  Não tenho conhecimento sobre esse tipo de inve...          Iniciante
# 2                                                Não          Iniciante
# 3                                                Sim          Iniciante
# 4  Não tenho conhecimento sobre esse tipo de inve...           Avançado
#
#                                  objetivo_financeiro  \
# 0                                   Comprar uma casa
# 1  Juntar dinheiro para uma meta de curto prazo (...
# 2  Juntar dinheiro para uma meta de curto prazo (...
# 3                               Construir patrimônio
# 4                                     Viver de renda
#
#                                   decisao_financeira  \
# 0  Estou disposto(a) a aprender e assumir novas e...
# 1         Busco equilibrar segurança e rentabilidade
# 2  Prefiro decisões seguras, mesmo que o retorno ...
# 3  Estou disposto(a) a aprender e assumir novas e...
# 4  Prefiro decisões seguras, mesmo que o retorno ...
#
#                                  jornada_financeira  \
# 0     Pretendo criar uma reserva financeira sólida.
# 1  Aprendi que cada pequena economia faz diferença.
# 2        Sonho em viver de renda passiva no futuro.
# 3        Meu objetivo é diversificar investimentos.
# 4             Aprendi a importância de poupar cedo.
#
#                                  conselho_financeiro                     email
# 0  Aprender sobre finanças é tão importante quant...      joao.silva@gmail.com
# 1  Diversifique seus investimentos para reduzir r...   pedro.almeida@gmail.com
# 2  Equilibre segurança e rentabilidade nos invest...    rafael.costa@gmail.com
# 3        Comece a poupar cedo, mesmo que seja pouco.    carla.santos@gmail.com
# 4  Evite dívidas desnecessárias e priorize invest...  juliana.farias@gmail.com

# %%
tabela_textos_livres = df_limpo[['jornada_financeira', 'conselho_financeiro']].copy()


for col in tabela_textos_livres.columns:
    tabela_textos_livres[col] = tabela_textos_livres[col].astype(str).str.strip()

CAMINHO_TEXTOS = "tabela_textos_livres.csv"
tabela_textos_livres.to_csv(CAMINHO_TEXTOS, index=False, encoding="utf-8")
files.download(CAMINHO_TEXTOS)

print("✔ Arquivo CSV da tabela_textos_livres gerado com sucesso:")
print(CAMINHO_TEXTOS)

tabela_textos_livres.head()
# Out:
# ✔ Arquivo CSV da tabela_textos_livres gerado com sucesso:
# tabela_textos_livres.csv
#                                  jornada_financeira  \
# 0     Pretendo criar uma reserva financeira sólida.
# 1  Aprendi que cada pequena economia faz diferença.
# 2        Sonho em viver de renda passiva no futuro.
# 3        Meu objetivo é diversificar investimentos.
# 4             Aprendi a importância de poupar cedo.
#
#                                  conselho_financeiro
# 0  Aprender sobre finanças é tão importante quant...
# 1  Diversifique seus investimentos para reduzir r...
# 2  Equilibre segurança e rentabilidade nos invest...
# 3        Comece a poupar cedo, mesmo que seja pouco.
# 4  Evite dívidas desnecessárias e priorize invest...

# %%
def normalizar_sim_nao(valor):
    if isinstance(valor, str):
        v = valor.strip().lower()
        if "sim" in v:
            return "Sim"
        elif "não" in v or "nao" in v:
            return "Não"
    return "Não"

for col in ['poupanca','tesouro','renda_fixa','renda_variavel','reserva_valor']:
    if col in df_limpo.columns:
        df_limpo[col] = df_limpo[col].apply(normalizar_sim_nao)

df_limpo.head()
# Out:
#   faixa_etaria                        participa_apostas reserva_financeira  \
# 0      18 - 25         Não Participo Desse Tipo De Jogo                Não
# 1        41-60         Não Participo Desse Tipo De Jogo                Não
# 2          60+  Sim, Mas De Forma Eventual E Controlada                Não
# 3          60+  Sim, Mas De Forma Eventual E Controlada                Não
# 4        41-60  Sim, Mas De Forma Eventual E Controlada                Não
#
#        resgate_imediato poupanca tesouro renda_fixa renda_variavel  \
# 0                   Não      Não     Sim        Sim            Não
# 1                   Sim      Não     Não        Sim            Não
# 2  Não possuo a reserva      Não     Não        Não            Não
# 3                   Não      Sim     Não        Sim            Não
# 4  Não possuo a reserva      Sim     Não        Não            Não
#
#   reserva_valor nivel_conhecimento  \
# 0           Não      Intermediário
# 1           Não          Iniciante
# 2           Não          Iniciante
# 3           Sim          Iniciante
# 4           Não           Avançado
#
#                                  objetivo_financeiro  \
# 0                                   Comprar uma casa
# 1  Juntar dinheiro para uma meta de curto prazo (...
# 2  Juntar dinheiro para uma meta de curto prazo (...
# 3                               Construir patrimônio
# 4                                     Viver de renda
#
#                                   decisao_financeira  \
# 0  Estou disposto(a) a aprender e assumir novas e...
# 1         Busco equilibrar segurança e rentabilidade
# 2  Prefiro decisões seguras, mesmo que o retorno ...
# 3  Estou disposto(a) a aprender e assumir novas e...
# 4  Prefiro decisões seguras, mesmo que o retorno ...
#
#                                  jornada_financeira  \
# 0     Pretendo criar uma reserva financeira sólida.
# 1  Aprendi que cada pequena economia faz diferença.
# 2        Sonho em viver de renda passiva no futuro.
# 3        Meu objetivo é diversificar investimentos.
# 4             Aprendi a importância de poupar cedo.
#
#                                  conselho_financeiro                     email
# 0  Aprender sobre finanças é tão importante quant...      joao.silva@gmail.com
# 1  Diversifique seus investimentos para reduzir r...   pedro.almeida@gmail.com
# 2  Equilibre segurança e rentabilidade nos invest...    rafael.costa@gmail.com
# 3        Comece a poupar cedo, mesmo que seja pouco.    carla.santos@gmail.com
# 4  Evite dívidas desnecessárias e priorize invest...  juliana.farias@gmail.com

# %%
tabela_investimentos = df_limpo.groupby('nivel_conhecimento').agg(
    Poupanca=('poupanca', lambda x: (x=='Sim').sum()),
    Tesouro=('tesouro', lambda x: (x=='Sim').sum()),
    Renda_Fixa=('renda_fixa', lambda x: (x=='Sim').sum()),
    Renda_Variavel=('renda_variavel', lambda x: (x=='Sim').sum()),
    Reserva_Valor=('reserva_valor', lambda x: (x=='Sim').sum())
).reset_index()

tabela_investimentos.to_csv('tabela_investimentos.csv', index=False)
files.download('tabela_investimentos.csv')

tabela_investimentos
# Out:
#   nivel_conhecimento  Poupanca  Tesouro  Renda_Fixa  Renda_Variavel  \
# 0           Avançado        14       15          17              12
# 1          Iniciante        13       16          15              12
# 2      Intermediário        14       18          15              13
#
#    Reserva_Valor
# 0             16
# 1             15
# 2             17

# %%
tabela_investimeto_por_nivel = df_limpo.groupby(['nivel_conhecimento','poupanca','tesouro','renda_fixa','renda_variavel','reserva_valor']).size().reset_index(name='quantidade')

CAMINHO_INVESTIMENTOS_POR_NIVEL = 'tabela_investimeto(investimentos por nível de conhecimento).csv'
tabela_investimeto_por_nivel.to_csv(CAMINHO_INVESTIMENTOS_POR_NIVEL, index=False)
files.download(CAMINHO_INVESTIMENTOS_POR_NIVEL)

tabela_investimeto_por_nivel
# Out:
#    nivel_conhecimento poupanca tesouro renda_fixa renda_variavel  \
# 0            Avançado      Não     Não        Não            Não
# 1            Avançado      Não     Não        Não            Não
# 2            Avançado      Não     Não        Não            Sim
# 3            Avançado      Não     Não        Sim            Não
# 4            Avançado      Não     Não        Sim            Não
# ..                ...      ...     ...        ...            ...
# 58      Intermediário      Sim     Não        Sim            Não
# 59      Intermediário      Sim     Sim        Não            Não
# 60      Intermediário      Sim     Sim        Não            Não
# 61      Intermediário      Sim     Sim        Não            Sim
# 62      Intermediário      Sim     Sim        Sim            Não
#
#    reserva_valor  quantidade
# 0            Não           6
# 1            Sim           3
# 2            Não           3
# 3            Não           5
# 4            Sim           3
# ..           ...         ...
# 58           Sim           1
# 59           Não           1
# 60           Sim           1
# 61           Não           1
# 62           Não           1
#
# [63 rows x 7 columns]

# %%
tabela_faixa = df_limpo.groupby(['faixa_etaria','nivel_conhecimento']).size().reset_index(name='quantidade')

CAMINHO_FAIXA = 'tabela_faixa.csv'
tabela_faixa.to_csv(CAMINHO_FAIXA, index=False)
files.download('tabela_faixa.csv')

tabela_faixa
# Out:
#    faixa_etaria nivel_conhecimento  quantidade
# 0       18 - 25           Avançado          12
# 1       18 - 25          Iniciante          13
# 2       18 - 25      Intermediário          14
# 3       26 - 40           Avançado          10
# 4       26 - 40          Iniciante          11
# 5       26 - 40      Intermediário          15
# 6         41-60           Avançado          12
# 7         41-60          Iniciante           8
# 8         41-60      Intermediário           8
# 9           60+           Avançado          11
# 10          60+          Iniciante          11
# 11          60+      Intermediário          12

# %%
tabela_objetivo = df_limpo.groupby(['nivel_conhecimento','objetivo_financeiro']).size().reset_index(name='quantidade')
tabela_objetivo
# Out:
#    nivel_conhecimento                                objetivo_financeiro  \
# 0            Avançado                                   Comprar uma casa
# 1            Avançado                               Construir patrimônio
# 2            Avançado  Juntar dinheiro para uma meta de curto prazo (...
# 3            Avançado                                     Viver de renda
# 4           Iniciante                                   Comprar uma casa
# 5           Iniciante                               Construir patrimônio
# 6           Iniciante  Juntar dinheiro para uma meta de curto prazo (...
# 7           Iniciante                                     Viver de renda
# 8       Intermediário                                   Comprar uma casa
# 9       Intermediário                               Construir patrimônio
# 10      Intermediário  Juntar dinheiro para uma meta de curto prazo (...
# 11      Intermediário                                     Viver de renda
#
#     quantidade
# 0           13
# 1            9
# 2           14
# 3            9
# 4           12
# 5           13
# 6           11
# 7            7
# 8           14
# 9           11
# 10          12
# 11          12

# %%
tabela_decisao = df_limpo.groupby(['nivel_conhecimento','decisao_financeira']).size().reset_index(name='quantidade')
tabela_decisao
# Out:
#   nivel_conhecimento                                 decisao_financeira  \
# 0           Avançado         Busco equilibrar segurança e rentabilidade
# 1           Avançado  Estou disposto(a) a aprender e assumir novas e...
# 2           Avançado  Prefiro decisões seguras, mesmo que o retorno ...
# 3          Iniciante         Busco equilibrar segurança e rentabilidade
# 4          Iniciante  Estou disposto(a) a aprender e assumir novas e...
# 5          Iniciante  Prefiro decisões seguras, mesmo que o retorno ...
# 6      Intermediário         Busco equilibrar segurança e rentabilidade
# 7      Intermediário  Estou disposto(a) a aprender e assumir novas e...
# 8      Intermediário  Prefiro decisões seguras, mesmo que o retorno ...
#
#    quantidade
# 0          17
# 1          15
# 2          13
# 3          14
# 4          15
# 5          14
# 6          15
# 7          13
# 8          21

# %%
tabela_jornada = df_limpo.groupby(['nivel_conhecimento','jornada_financeira']).size().reset_index(name='quantidade')
tabela_jornada
# Out:
#    nivel_conhecimento                                 jornada_financeira  \
# 0            Avançado              Aprendi a importância de poupar cedo.
# 1            Avançado              Tenho o sonho de investir em imóveis.
# 2            Avançado                                                nan
# 3           Iniciante   Aprendi que cada pequena economia faz diferença.
# 4           Iniciante             Busco planejar melhor minhas finanças.
# 5           Iniciante  Estou aprendendo a equilibrar gastos e investi...
# 6           Iniciante         Meu objetivo é diversificar investimentos.
# 7           Iniciante          Quero construir patrimônio com segurança.
# 8           Iniciante         Sonho em viver de renda passiva no futuro.
# 9           Iniciante                                                nan
# 10      Intermediário              Já me arrependi de gastos impulsivos.
# 11      Intermediário      Pretendo criar uma reserva financeira sólida.
# 12      Intermediário                                                nan
#
#     quantidade
# 0            1
# 1            1
# 2           43
# 3            1
# 4            1
# 5            1
# 6            1
# 7            1
# 8            1
# 9           37
# 10           1
# 11           1
# 12          47

# %%
tabela_comparativa = df_limpo.groupby(
    ['nivel_conhecimento', 'objetivo_financeiro', 'decisao_financeira', 'jornada_financeira']
).size().reset_index(name='quantidade')

tabela_comparativa = tabela_comparativa.sort_values(by='quantidade', ascending=False)
tabela_comparativa
# Out:
#    nivel_conhecimento                                objetivo_financeiro  \
# 18          Iniciante                                   Comprar uma casa
# 21          Iniciante                               Construir patrimônio
# 35      Intermediário                                   Comprar uma casa
# 0            Avançado                                   Comprar uma casa
# 45      Intermediário                                     Viver de renda
# 8            Avançado  Juntar dinheiro para uma meta de curto prazo (...
# 42      Intermediário  Juntar dinheiro para uma meta de curto prazo (...
# 28          Iniciante  Juntar dinheiro para uma meta de curto prazo (...
# 37      Intermediário                               Construir patrimônio
# 19          Iniciante                               Construir patrimônio
# 4            Avançado                               Construir patrimônio
# 9            Avançado  Juntar dinheiro para uma meta de curto prazo (...
# 7            Avançado  Juntar dinheiro para uma meta de curto prazo (...
# 2            Avançado                                   Comprar uma casa
# 39      Intermediário                               Construir patrimônio
# 43      Intermediário                                     Viver de renda
# 41      Intermediário  Juntar dinheiro para uma meta de curto prazo (...
# 30          Iniciante                                     Viver de renda
# 10           Avançado                                     Viver de renda
# 1            Avançado                                   Comprar uma casa
# 3            Avançado                               Construir patrimônio
# 11           Avançado                                     Viver de renda
# 44      Intermediário                                     Viver de renda
# 34      Intermediário                                   Comprar uma casa
# 40      Intermediário  Juntar dinheiro para uma meta de curto prazo (...
# 32      Intermediário                                   Comprar uma casa
# 24          Iniciante  Juntar dinheiro para uma meta de curto prazo (...
# 29          Iniciante                                     Viver de renda
# 13           Avançado                                     Viver de renda
# 5            Avançado                               Construir patrimônio
# 38      Intermediário                               Construir patrimônio
# 15          Iniciante                                   Comprar uma casa
# 12           Avançado                                     Viver de renda
# 6            Avançado  Juntar dinheiro para uma meta de curto prazo (...
# 26          Iniciante  Juntar dinheiro para uma meta de curto prazo (...
# 16          Iniciante                                   Comprar uma casa
# 14          Iniciante                                   Comprar uma casa
# 20          Iniciante                               Construir patrimônio
# 17          Iniciante                                   Comprar uma casa
# 27          Iniciante  Juntar dinheiro para uma meta de curto prazo (...
# 23          Iniciante  Juntar dinheiro para uma meta de curto prazo (...
# 25          Iniciante  Juntar dinheiro para uma meta de curto prazo (...
# 22          Iniciante                               Construir patrimônio
# 36      Intermediário                               Construir patrimônio
# 31          Iniciante                                     Viver de renda
# 33      Intermediário                                   Comprar uma casa
#
#                                    decisao_financeira  \
# 18  Prefiro decisões seguras, mesmo que o retorno ...
# 21  Estou disposto(a) a aprender e assumir novas e...
# 35  Prefiro decisões seguras, mesmo que o retorno ...
# 0          Busco equilibrar segurança e rentabilidade
# 45  Prefiro decisões seguras, mesmo que o retorno ...
# 8   Estou disposto(a) a aprender e assumir novas e...
# 42  Prefiro decisões seguras, mesmo que o retorno ...
# 28  Prefiro decisões seguras, mesmo que o retorno ...
# 37         Busco equilibrar segurança e rentabilidade
# 19         Busco equilibrar segurança e rentabilidade
# 4   Estou disposto(a) a aprender e assumir novas e...
# 9   Prefiro decisões seguras, mesmo que o retorno ...
# 7          Busco equilibrar segurança e rentabilidade
# 2   Prefiro decisões seguras, mesmo que o retorno ...
# 39  Prefiro decisões seguras, mesmo que o retorno ...
# 43         Busco equilibrar segurança e rentabilidade
# 41  Estou disposto(a) a aprender e assumir novas e...
# 30  Estou disposto(a) a aprender e assumir novas e...
# 10         Busco equilibrar segurança e rentabilidade
# 1   Estou disposto(a) a aprender e assumir novas e...
# 3          Busco equilibrar segurança e rentabilidade
# 11  Estou disposto(a) a aprender e assumir novas e...
# 44  Estou disposto(a) a aprender e assumir novas e...
# 34  Estou disposto(a) a aprender e assumir novas e...
# 40         Busco equilibrar segurança e rentabilidade
# 32         Busco equilibrar segurança e rentabilidade
# 24         Busco equilibrar segurança e rentabilidade
# 29         Busco equilibrar segurança e rentabilidade
# 13  Prefiro decisões seguras, mesmo que o retorno ...
# 5   Prefiro decisões seguras, mesmo que o retorno ...
# 38  Estou disposto(a) a aprender e assumir novas e...
# 15         Busco equilibrar segurança e rentabilidade
# 12  Prefiro decisões seguras, mesmo que o retorno ...
# 6          Busco equilibrar segurança e rentabilidade
# 26  Estou disposto(a) a aprender e assumir novas e...
# 16  Estou disposto(a) a aprender e assumir novas e...
# 14         Busco equilibrar segurança e rentabilidade
# 20  Estou disposto(a) a aprender e assumir novas e...
# 17  Estou disposto(a) a aprender e assumir novas e...
# 27  Prefiro decisões seguras, mesmo que o retorno ...
# 23         Busco equilibrar segurança e rentabilidade
# 25  Estou disposto(a) a aprender e assumir novas e...
# 22  Prefiro decisões seguras, mesmo que o retorno ...
# 36         Busco equilibrar segurança e rentabilidade
# 31  Prefiro decisões seguras, mesmo que o retorno ...
# 33  Estou disposto(a) a aprender e assumir novas e...
#
#                                    jornada_financeira  quantidade
# 18                                                nan           7
# 21                                                nan           7
# 35                                                nan           7
# 0                                                 nan           6
# 45                                                nan           5
# 8                                                 nan           5
# 42                                                nan           5
# 28                                                nan           4
# 37                                                nan           4
# 19                                                nan           4
# 4                                                 nan           4
# 9                                                 nan           4
# 7                                                 nan           4
# 2                                                 nan           4
# 39                                                nan           4
# 43                                                nan           4
# 41                                                nan           4
# 30                                                nan           3
# 10                                                nan           3
# 1                                                 nan           3
# 3                                                 nan           3
# 11                                                nan           3
# 44                                                nan           3
# 34                                                nan           3
# 40                                                nan           3
# 32                                                nan           3
# 24                                                nan           3
# 29                                                nan           3
# 13                                                nan           2
# 5                                                 nan           2
# 38                                                nan           2
# 15                                                nan           2
# 12              Aprendi a importância de poupar cedo.           1
# 6               Tenho o sonho de investir em imóveis.           1
# 26                                                nan           1
# 16  Estou aprendendo a equilibrar gastos e investi...           1
# 14             Busco planejar melhor minhas finanças.           1
# 20         Meu objetivo é diversificar investimentos.           1
# 17                                                nan           1
# 27         Sonho em viver de renda passiva no futuro.           1
# 23   Aprendi que cada pequena economia faz diferença.           1
# 25          Quero construir patrimônio com segurança.           1
# 22                                                nan           1
# 36              Já me arrependi de gastos impulsivos.           1
# 31                                                nan           1
# 33      Pretendo criar uma reserva financeira sólida.           1

# %%
def valor_mais_frequente(series):
    return series.mode()[0] if not series.mode().empty else None

tabela_resumo = df_limpo.groupby('faixa_etaria').agg(
    total_pessoas=('faixa_etaria', 'count'),
    nivel_conhecimento_mais_comum=('nivel_conhecimento', valor_mais_frequente),
    pessoas_com_reserva=('reserva_financeira', lambda x: (x == 'Sim').sum()),
    pessoas_que_apostam=('participa_apostas', lambda x: (x.str.contains('Sim')).sum())  # <-- nome correto
).reset_index()

tabela_resumo
# Out:
#   faixa_etaria  total_pessoas nivel_conhecimento_mais_comum  \
# 0      18 - 25             39                 Intermediário
# 1      26 - 40             36                 Intermediário
# 2        41-60             28                      Avançado
# 3          60+             34                 Intermediário
#
#    pessoas_com_reserva  pessoas_que_apostam
# 0                   16                   21
# 1                    8                   19
# 2                    6                   13
# 3                   12                   19

# %%
def valor_mais_frequente(series):
    return series.mode()[0] if not series.mode().empty else None

tabela_completa = df_limpo.groupby('faixa_etaria').agg(
    total_pessoas=('faixa_etaria', 'count'),
    nivel_conhecimento_mais_comum=('nivel_conhecimento', valor_mais_frequente),
    pessoas_com_reserva=('reserva_financeira', lambda x: (x == 'Sim').sum()),
    pessoas_que_apostam=('participa_apostas', lambda x: (x.str.contains('Sim')).sum()),
    poupanca=('poupanca', lambda x: (x == 'Sim').sum()),
    tesouro=('tesouro', lambda x: (x == 'Sim').sum()),
    renda_fixa=('renda_fixa', lambda x: (x == 'Sim').sum()),
    renda_variavel=('renda_variavel', lambda x: (x == 'Sim').sum()),
    objetivo_financeiro_mais_comum=('objetivo_financeiro', valor_mais_frequente)
).reset_index()

tabela_completa.to_csv('tabela_completa.csv', index=False)
files.download('tabela_completa.csv')

tabela_completa
# Out:
#   faixa_etaria  total_pessoas nivel_conhecimento_mais_comum  \
# 0      18 - 25             39                 Intermediário
# 1      26 - 40             36                 Intermediário
# 2        41-60             28                      Avançado
# 3          60+             34                 Intermediário
#
#    pessoas_com_reserva  pessoas_que_apostam  poupanca  tesouro  renda_fixa  \
# 0                   16                   21        13       13          18
# 1                    8                   19        12       13           9
# 2                    6                   13         7       10          10
# 3                   12                   19         9       13          10
#
#    renda_variavel                     objetivo_financeiro_mais_comum
# 0              13                               Construir patrimônio
# 1               5                                   Comprar uma casa
# 2               5                                   Comprar uma casa
# 3              14  Juntar dinheiro para uma meta de curto prazo (...

# %%
if 'resgate_imediato' not in df_limpo.columns:
    df_limpo['resgate_imediato'] = df_limpo['Resgate imediato'].str.strip().str.title()

def contar_sim(series):
    return (series == 'Sim').sum()

tabela_comportamental = df_limpo.groupby('faixa_etaria').agg(
    total_pessoas=('faixa_etaria', 'count'),
    pessoas_que_apostam=('participa_apostas', lambda x: x.str.contains('Sim').sum()),  # nome atualizado
    pessoas_com_resgate_imediato=('resgate_imediato', contar_sim),
    pessoas_com_reserva=('reserva_financeira', contar_sim),
    pessoas_com_conhecimento_avancado=('nivel_conhecimento', lambda x: (x == 'Avançado').sum())
).reset_index()

tabela_comportamental.to_csv('tabela_comportamental.csv', index=False)
files.download('tabela_comportamental.csv')

tabela_comportamental
# Out:
#   faixa_etaria  total_pessoas  pessoas_que_apostam  \
# 0      18 - 25             39                   21
# 1      26 - 40             36                   19
# 2        41-60             28                   13
# 3          60+             34                   19
#
#    pessoas_com_resgate_imediato  pessoas_com_reserva  \
# 0                             5                   16
# 1                            11                    8
# 2                            10                    6
# 3                             9                   12
#
#    pessoas_com_conhecimento_avancado
# 0                                 12
# 1                                 10
# 2                                 12
# 3                                 11

# %%
if 'objetivo_financeiro' not in df_limpo.columns:
    df_limpo['objetivo_financeiro'] = df_limpo['Objetivo financeiro'].str.strip().str.title()

tabela_perfil_pessoa = df_limpo.groupby(['faixa_etaria', 'nivel_conhecimento', 'objetivo_financeiro', 'email']).size().reset_index(name='quantidade')

tabela_perfil_pessoa.to_csv('tabela_perfil_pessoa.csv', index=False)
files.download('tabela_perfil_pessoa.csv')

tabela_perfil_pessoa
# Out:
#    faixa_etaria nivel_conhecimento  \
# 0       18 - 25           Avançado
# 1       18 - 25           Avançado
# 2       18 - 25           Avançado
# 3       18 - 25           Avançado
# 4       18 - 25          Iniciante
# 5       18 - 25          Iniciante
# 6       18 - 25          Iniciante
# 7       18 - 25          Iniciante
# 8       18 - 25          Iniciante
# 9       18 - 25      Intermediário
# 10      18 - 25      Intermediário
# 11      18 - 25      Intermediário
# 12      18 - 25      Intermediário
# 13      18 - 25      Intermediário
# 14      26 - 40           Avançado
# 15      26 - 40           Avançado
# 16      26 - 40           Avançado
# 17      26 - 40           Avançado
# 18      26 - 40          Iniciante
# 19      26 - 40          Iniciante
# 20      26 - 40          Iniciante
# 21      26 - 40          Iniciante
# 22      26 - 40          Iniciante
# 23      26 - 40      Intermediário
# 24      26 - 40      Intermediário
# 25      26 - 40      Intermediário
# 26      26 - 40      Intermediário
# 27        41-60           Avançado
# 28        41-60           Avançado
# 29        41-60           Avançado
# 30        41-60           Avançado
# 31        41-60           Avançado
# 32        41-60          Iniciante
# 33        41-60          Iniciante
# 34        41-60          Iniciante
# 35        41-60          Iniciante
# 36        41-60          Iniciante
# 37        41-60      Intermediário
# 38        41-60      Intermediário
# 39        41-60      Intermediário
# 40        41-60      Intermediário
# 41          60+           Avançado
# 42          60+           Avançado
# 43          60+           Avançado
# 44          60+           Avançado
# 45          60+          Iniciante
# 46          60+          Iniciante
# 47          60+          Iniciante
# 48          60+          Iniciante
# 49          60+          Iniciante
# 50          60+          Iniciante
# 51          60+      Intermediário
# 52          60+      Intermediário
# 53          60+      Intermediário
# 54          60+      Intermediário
#
#                                   objetivo_financeiro  \
# 0                                    Comprar uma casa
# 1                                Construir patrimônio
# 2   Juntar dinheiro para uma meta de curto prazo (...
# 3                                      Viver de renda
# 4                                    Comprar uma casa
# 5                                    Comprar uma casa
# 6                                Construir patrimônio
# 7   Juntar dinheiro para uma meta de curto prazo (...
# 8                                      Viver de renda
# 9                                    Comprar uma casa
# 10                                   Comprar uma casa
# 11                               Construir patrimônio
# 12  Juntar dinheiro para uma meta de curto prazo (...
# 13                                     Viver de renda
# 14                                   Comprar uma casa
# 15                               Construir patrimônio
# 16  Juntar dinheiro para uma meta de curto prazo (...
# 17                                     Viver de renda
# 18                                   Comprar uma casa
# 19                               Construir patrimônio
# 20  Juntar dinheiro para uma meta de curto prazo (...
# 21  Juntar dinheiro para uma meta de curto prazo (...
# 22                                     Viver de renda
# 23                                   Comprar uma casa
# 24                               Construir patrimônio
# 25  Juntar dinheiro para uma meta de curto prazo (...
# 26                                     Viver de renda
# 27                                   Comprar uma casa
# 28                               Construir patrimônio
# 29  Juntar dinheiro para uma meta de curto prazo (...
# 30  Juntar dinheiro para uma meta de curto prazo (...
# 31                                     Viver de renda
# 32                                   Comprar uma casa
# 33                                   Comprar uma casa
# 34                               Construir patrimônio
# 35  Juntar dinheiro para uma meta de curto prazo (...
# 36                                     Viver de renda
# 37                                   Comprar uma casa
# 38                               Construir patrimônio
# 39  Juntar dinheiro para uma meta de curto prazo (...
# 40                                     Viver de renda
# 41                                   Comprar uma casa
# 42                               Construir patrimônio
# 43  Juntar dinheiro para uma meta de curto prazo (...
# 44                                     Viver de renda
# 45                                   Comprar uma casa
# 46                               Construir patrimônio
# 47                               Construir patrimônio
# 48  Juntar dinheiro para uma meta de curto prazo (...
# 49  Juntar dinheiro para uma meta de curto prazo (...
# 50                                     Viver de renda
# 51                                   Comprar uma casa
# 52                               Construir patrimônio
# 53  Juntar dinheiro para uma meta de curto prazo (...
# 54                                     Viver de renda
#
#                           email  quantidade
# 0                           nan           2
# 1                           nan           4
# 2                           nan           2
# 3                           nan           4
# 4     camila.ferreira@gmail.com           1
# 5                           nan           2
# 6                           nan           5
# 7                           nan           4
# 8                           nan           1
# 9          joao.silva@gmail.com           1
# 10                          nan           2
# 11                          nan           5
# 12                          nan           4
# 13                          nan           2
# 14                          nan           4
# 15                          nan           1
# 16                          nan           3
# 17                          nan           2
# 18                          nan           3
# 19                          nan           2
# 20     maria.oliveira@gmail.com           1
# 21                          nan           2
# 22                          nan           3
# 23                          nan           5
# 24                          nan           3
# 25                          nan           5
# 26                          nan           2
# 27                          nan           6
# 28                          nan           1
# 29       felipe.gomes@gmail.com           1
# 30                          nan           3
# 31     juliana.farias@gmail.com           1
# 32  isabela.rodrigues@gmail.com           1
# 33                          nan           2
# 34                          nan           2
# 35      pedro.almeida@gmail.com           1
# 36                          nan           2
# 37                          nan           3
# 38        lucas.moura@gmail.com           1
# 39                          nan           1
# 40                          nan           3
# 41                          nan           1
# 42                          nan           3
# 43                          nan           5
# 44                          nan           2
# 45                          nan           3
# 46       carla.santos@gmail.com           1
# 47                          nan           3
# 48                          nan           2
# 49       rafael.costa@gmail.com           1
# 50                          nan           1
# 51                          nan           3
# 52                          nan           2
# 53                          nan           2
# 54                          nan           5

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Agrupar por faixa etária
total_por_faixa = df_limpo.groupby('faixa_etaria').size().reset_index(name='quantidade')

# Ordenar por faixa etária se possível
total_por_faixa = total_por_faixa.sort_values('faixa_etaria')

# Plot
plt.figure(figsize=(10,6))
sns.barplot(data=total_por_faixa, x='faixa_etaria', y='quantidade', palette="viridis")
plt.title('Total de Pessoas por Faixa Etária', fontsize=16)
plt.xlabel('Faixa Etária', fontsize=12)
plt.ylabel('Número Total de Pessoas', fontsize=12)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3204752474.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=total_por_faixa, x='faixa_etaria', y='quantidade', palette="viridis")

# %%
total_por_nivel = df_limpo.groupby('nivel_conhecimento').size().reset_index(name='quantidade')

plt.figure(figsize=(10,6))
sns.lineplot(data=total_por_nivel, x='nivel_conhecimento', y='quantidade', marker='o')
plt.title('Total de Pessoas por Nível de Conhecimento')
plt.xlabel('Nível de Conhecimento')
plt.ylabel('Número Total de Pessoas')
plt.ylim(0, df_limpo.shape[0])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid", palette="deep")
plt.rcParams['figure.figsize'] = (12, 7)

df_limpo['faixa_etaria'] = df_limpo['faixa_etaria'].str.strip()
df_limpo['nivel_conhecimento'] = df_limpo['nivel_conhecimento'].str.strip().str.title()

conhecimento_por_faixa = (
    df_limpo.groupby(['faixa_etaria', 'nivel_conhecimento'])
    .size()
    .reset_index(name='quantidade')
)

plt.figure(figsize=(12, 7))
sns.lineplot(
    data=conhecimento_por_faixa,
    x='faixa_etaria',
    y='quantidade',
    hue='nivel_conhecimento',
    marker='o'
)

plt.title('Nível de Conhecimento Financeiro por Faixa Etária')
plt.xlabel('Faixa Etária')
plt.ylabel('Número de Pessoas')
plt.ylim(0, df_limpo.shape[0])
plt.legend(title='Nível de Conhecimento')
plt.tight_layout()
plt.show()

# %%
sns.set_theme(style="whitegrid", palette="deep")
plt.rcParams['figure.figsize'] = (10, 6)

reserva_por_faixa = df_limpo.groupby(['faixa_etaria']).agg(
    pessoas_com_reserva=('reserva_financeira', lambda x: (x == 'Sim').sum())
).reset_index()

plt.figure(figsize=(10,6))
sns.lineplot(
    data=reserva_por_faixa,
    x='faixa_etaria',
    y='pessoas_com_reserva',
    marker='o',
    color='green'
)
plt.title('Pessoas com Reserva Financeira por Faixa Etária')
plt.xlabel('Faixa Etária')
plt.ylabel('Número de Pessoas')
plt.ylim(0, df_limpo.shape[0])
plt.tight_layout()
plt.show()

# %%
apostas_por_faixa = df_limpo.groupby('faixa_etaria').agg(
    pessoas_que_apostam=('participa_apostas', lambda x: x.str.contains('Sim').sum())
).reset_index()

plt.figure(figsize=(10,6))
sns.lineplot(
    data=apostas_por_faixa,
    x='faixa_etaria',
    y='pessoas_que_apostam',
    marker='o',
    color='red'
)
plt.title('Participação em Apostas por Faixa Etária')
plt.xlabel('Faixa Etária')
plt.ylabel('Número de Pessoas')
plt.ylim(0, df_limpo.shape[0])
plt.tight_layout()
plt.show()

# %%
investimentos_por_faixa = df_limpo.groupby('faixa_etaria').agg(
    poupanca=('poupanca', lambda x: (x == 'Sim').sum()),
    tesouro=('tesouro', lambda x: (x == 'Sim').sum()),
    renda_fixa=('renda_fixa', lambda x: (x == 'Sim').sum()),
    renda_variavel=('renda_variavel', lambda x: (x == 'Sim').sum())
).reset_index()

plt.figure(figsize=(10,6))
sns.lineplot(data=investimentos_por_faixa, x='faixa_etaria', y='poupanca', marker='o', label='Poupança')
sns.lineplot(data=investimentos_por_faixa, x='faixa_etaria', y='tesouro', marker='o', label='Tesouro Nacional')
sns.lineplot(data=investimentos_por_faixa, x='faixa_etaria', y='renda_fixa', marker='o', label='Renda Fixa')
sns.lineplot(data=investimentos_por_faixa, x='faixa_etaria', y='renda_variavel', marker='o', label='Renda Variável')

plt.title('Investimentos por Faixa Etária')
plt.xlabel('Faixa Etária')
plt.ylabel('Número de Pessoas')
plt.ylim(0, df_limpo.shape[0])
plt.legend(title='Investimento')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

conhecimento_objetivo = (
    df_limpo.groupby(['nivel_conhecimento', 'objetivo_financeiro'])
    .size()
    .reset_index(name='quantidade')
)

plt.figure(figsize=(14,7))

sns.lineplot(
    data=conhecimento_objetivo,
    x='nivel_conhecimento',
    y='quantidade',
    hue='objetivo_financeiro',
    marker='o'
)

plt.title('Objetivo Financeiro por Nível de Conhecimento')
plt.xlabel('Nível de Conhecimento')
plt.ylabel('Número de Pessoas')
plt.xticks(rotation=30)
plt.ylim(0, df_limpo.shape[0])

plt.legend(title='Objetivo Financeiro', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,6))
conhecimento_idade = df_limpo.groupby(['faixa_etaria', 'nivel_conhecimento']).size().reset_index(name='quantidade')
conhecimento_pivot = conhecimento_idade.pivot(index='faixa_etaria', columns='nivel_conhecimento', values='quantidade').fillna(0)

conhecimento_pivot.plot(kind='bar', stacked=True, figsize=(12,6), colormap='viridis')

plt.title('Distribuição do Nível de Conhecimento Financeiro por Faixa Etária')
plt.xlabel('Faixa Etária')
plt.ylabel('Número de Pessoas')
plt.legend(title='Nível de Conhecimento')
plt.tight_layout()
plt.show()

# %%
reserva_por_nivel = df_limpo.groupby('nivel_conhecimento')['reserva_financeira'].apply(lambda x: (x == 'Sim').mean() * 100).reset_index()

plt.figure(figsize=(8,5))
sns.barplot(data=reserva_por_nivel, x='nivel_conhecimento', y='reserva_financeira', palette='coolwarm')

plt.title('Percentual de Pessoas com Reserva Financeira por Nível de Conhecimento')
plt.xlabel('Nível de Conhecimento')
plt.ylabel('Percentual (%)')
plt.ylim(0, 100)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-2838818012.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=reserva_por_nivel, x='nivel_conhecimento', y='reserva_financeira', palette='coolwarm')

# %%
jornada_idade = df_limpo.groupby(['faixa_etaria', 'jornada_financeira']).size().reset_index(name='quantidade')
jornada_pivot = jornada_idade.pivot(index='faixa_etaria', columns='jornada_financeira', values='quantidade').fillna(0)

jornada_pivot.plot(kind='barh', stacked=True, figsize=(12,7), colormap='Paired')

plt.title('Jornada Financeira por Faixa Etária')
plt.xlabel('Número de Pessoas')
plt.ylabel('Faixa Etária')
plt.legend(title='Jornada Financeira')
plt.tight_layout()
plt.show()

# %%
decisao_conhecimento = df_limpo.groupby(['nivel_conhecimento', 'decisao_financeira']).size().reset_index(name='quantidade')

plt.figure(figsize=(12,6))
sns.barplot(data=decisao_conhecimento, x='nivel_conhecimento', y='quantidade', hue='decisao_financeira')

plt.title('Decisão Financeira por Nível de Conhecimento')
plt.xlabel('Nível de Conhecimento')
plt.ylabel('Número de Pessoas')
plt.legend(title='Decisão Financeira')
plt.tight_layout()
plt.show()

# %%
def simplificar_aposta(texto):
    t = str(texto).strip().lower()

    if "sim" in t:
        return "Sim"
    if "não" in t or "nao" in t:
        return "Não"

    return "Outro"


df_limpo["participa_simplificado"] = df_limpo["participa_apostas"].apply(simplificar_aposta)


contagem = df_limpo["participa_simplificado"].value_counts()
porcentagem = contagem / contagem.sum() * 100


plt.figure(figsize=(6,4))
bars = plt.bar(porcentagem.index, porcentagem.values)

plt.title("Porcentagem de pessoas que participam de apostas")
plt.ylabel("Porcentagem (%)")
plt.xlabel("Participa de apostas")
plt.xticks(rotation=0)


for bar, pct in zip(bars, porcentagem.values):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height(),
             f"{pct:.1f}%", ha="center", va="bottom")

plt.tight_layout()
plt.show()

# %%
def simplificar_reserva(texto):
    t = str(texto).strip().lower()

    if "sim" in t:
        return "Sim"
    if "não" in t or "nao" in t:
        return "Não"

    return "Outro"


df_limpo["reserva_simplificada"] = df_limpo["reserva_financeira"].apply(simplificar_reserva)


contagem_reserva = df_limpo["reserva_simplificada"].value_counts()
porcentagem_reserva = contagem_reserva / contagem_reserva.sum() * 100


plt.figure(figsize=(6,4))
bars = plt.bar(porcentagem_reserva.index, porcentagem_reserva.values)

plt.title("Porcentagem de pessoas que possuem reserva financeira")
plt.ylabel("Porcentagem (%)")
plt.xlabel("Possui reserva financeira?")
plt.xticks(rotation=0)

for bar, pct in zip(bars, porcentagem_reserva.values):
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height(),
             f"{pct:.1f}%", ha="center", va="bottom")

plt.tight_layout()
plt.show()
